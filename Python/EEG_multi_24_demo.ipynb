# %% [markdown]
# This is the jupyter notebook that replicates the results for the real data studies in Section 5 and Section S5.
#
# When I created this jupyter notebook, I used PyCharm and installed relevant packages under a virtual environment, denoted as ".venv".
#
# It takes longer than running the same file in PyCharm directly.
#
# You need to change the directory "parent_path_eeg_dir" to your own first.
#
# Make sure you have installed the following python modules:
# * numpy, scipy, seaborn, matplotlib, os
# * tqdm
# * jax, numpyro
# * sklearn, math
# * pyriemann, mne
# * json
#
# Due to the data confidentiality, we cannot provide the real dataset here, but the logic is similar to the real data based simulation studies.
#
# We will reproduce the plots and tables with available MCMC samples and prediction accuracy.
#
# You need to change the directory "parent_path_eeg_local" to your own one first.
#
# 1. Figure 5 to show the parameter estimates and the spatial pattern of xDAWN filters. Remember to set "sensitivity_bool=False". The default kernel-hyperparameter is [0.3, 1.2], and [0.2, 1.2]. Figure S9 also uses the python code with different subject ids.

# %%
# %run -i '~/Desktop/BSM-Code-V2/Python/EEG_signal_compare_ERP_xdawn_multi.py'
# Out:
# 7
# 9
# New subject name: K151
# 8
# 10
# New subject name: K151
# 8
# 11
# New subject name: K151
# 8
# 11
# New subject name: K151
# 9
# 12
# New subject name: K151
# 9
# 13
# New subject name: K151
# 9
# 13
# New subject name: K151
# 10
# 14
# New subject name: K151
# 11
# 15
# New subject name: K151
# 7
# 9
# New subject name: K151
# 8
# 10
# New subject name: K151
# 8
# 11
# New subject name: K151
# 8
# 11
# New subject name: K151
# 9
# 12
# New subject name: K151
# 9
# 13
# New subject name: K151
# 9
# 13
# New subject name: K151
# 10
# 14
# New subject name: K151
# 11
# 15
# New subject name: K151

# %% [markdown]
# 2. Figure S8 to perform the sensitivity check on parameter estimates across 9 combinations of hyperparameters.
#
# Remember to change "sensitivity_bool=True".

# %%
# %run -i '~/Desktop/BSM-Code-V2/Python/EEG_signal_compare_ERP_xdawn_multi.py'
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/Desktop/BSM-Code-V2/Python/.venv/lib/python3.8/site-packages/matplotlib_inline/backend_inline.py:126, in flush_figures()
#     123 if InlineBackend.instance().close_figures:
#     124     # ignore the tracking, just draw and close all figures
#     125     try:
# --> 126         return show(True)
#     127     except Exception as e:
#     128         # safely show traceback if in IPython, else raise
#     129         ip = get_ipython()
#
# File ~/Desktop/BSM-Code-V2/Python/.venv/lib/python3.8/site-packages/matplotlib_inline/backend_inline.py:90, in show(close, block)
#      88 try:
#      89     for figure_manager in Gcf.get_all_fig_managers():
# ---> 90         display(
#      91             figure_manager.canvas.figure,
#      92             metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
# ...

# %% [markdown]
# 3. Table S5 to summarize prediction accuracy of BSM-Mixture across 9 combinations of hyperparameters. The tabular outputs are saved in R.

# %%
# %load_ext rpy2.ipython
# Out:
# The rpy2.ipython extension is already loaded. To reload it, use:
#   %reload_ext rpy2.ipython

# %%
# %%R
# source("~/Desktop/BSM-Code-V2/R/eeg_prediction_frt_xdawn_multi_sensitivity.R")
# Out:
# [1] "K151"
# [1] "Table S5:"
#      [,1] [,2] [,3] [,4] [,5] [,6] [,7] [,8] [,9]
# [1,] 56.8 56.8 55.4 55.4 54.1 52.7 54.1 55.4 52.7
# [2,] 78.4 81.1 81.1 81.1 82.4 82.4 82.4 82.4 83.8
# [3,] 85.1 83.8 83.8 83.8 83.8 83.8 83.8 83.8 83.8
# [4,] 90.5 89.2 89.2 89.2 89.2 89.2 89.2 89.2 89.2
# [5,] 91.9 90.5 90.5 90.5 90.5 90.5 90.5 90.5 90.5
# [6,] 94.6 94.6 93.2 93.2 94.6 94.6 93.2 94.6 93.2

# %% [markdown]
# 4. Table 2 to report the prediction accuracy of all FRT files with up to 6 sequences by BSM-Mixture, MDWm, swLDA, and SMGP with 5 training sequences.

# %%
# %%R
# source("~/Desktop/BSM-Code-V2/R/eeg_prediction_3way_frt_xdawn_multi_per_participant.R")
# Out:
# [1] "K151"
#        BSM_Mixture      MDWM     swLDA      SMGP
# Test_1   0.5405405 0.4729730 0.3783784 0.1621622
# Test_2   0.8243243 0.7162162 0.5000000 0.2297297
# Test_3   0.8378378 0.7567568 0.6756757 0.4054054
# Test_4   0.9054054 0.8108108 0.7567568 0.3918919
# Test_5   0.9054054 0.9054054 0.8108108 0.5135135
# Test_6   0.9459459 0.9594595 0.8378378 0.4729730

# %% [markdown]
# 5. Figure 6

# %%
# %%R
# source("~/Desktop/BSM-Code-V2/R/eeg_prediction_3way_frt_xdawn_multi_compare.R")
# Out:
# [1] "K143"
# [1] "K145"
# [1] "K146"
# [1] "K147"
# [1] "K151"
# [1] "K155"
# [1] "K171"
# [1] "K177"
# [1] "K178"

# %% [markdown]
# The R code creates two plots under the folder "./EEG_MATLAB_data/FRT_files/Prediction/xDAWN_comp_2_reduced".
# * boxplot_predict_test_brain_damage_seq_train_size_5.png
# * spaghetti_plot_predict_test_brain_damage_seq_train_size_5.png

# %% [markdown]
# 5. Figure S10

# %%
# %%R
# source("~/Desktop/BSM-Code-V2/R/eeg_prediction_3way_frt_xdawn_multi.R")
# Out:
# [1] 5
# [1] "K143"
# [1] "K145"
# [1] "K146"
# [1] "K147"
# [1] "K151"
# [1] "K155"
# [1] "K171"
# [1] "K177"
# [1] "K178"

# %% [markdown]
# The R code creates one superimposed plot under the folder "./EEG_MATLAB_data/FRT_files/Prediction/xDAWN_comp_2_reduced".
# * plot_xDAWN_cluster_2_predict_test_fix_seq_train_size_5.png
#
# K151's information is not shown here due to the layout of the figure. Details can be found in Table 2.
